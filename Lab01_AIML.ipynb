# %% [markdown]
# <a href="https://colab.research.google.com/github/AshrithaPatturi/AIML_BATCH10/blob/main/Lab01_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Lab-01 Activity on Numpy,Pandas and MatplotLib

# %% [markdown]
# ##Part 1 – Implement Basic Data Structures using Numpy, Pandas
# 1. Lists
# 2. Arrays
# 3. Identify their type using type()
# 4. Perform mathematical operations on these datasets created - multiplication, division,
# poweroff
# 5. Combine text with Numpy fuction to generate a textual output - ”Addition of Two:
# array1 +array 2
# 6. Implement np.sin(), log(), log2(), np.exp())

# %% [markdown]
# ##1.Lists,2.Arrays

# %%
import numpy as np
list1 = [1,2,3]
array1 = np.array(list1)
array1
# Out:
# array([1, 2, 3])

# %% [markdown]
# ##3.Type

# %%
type(list1)
# Out:
# list

# %% [markdown]
# ##4.Mathematical Operations

# %% [markdown]
# Perform Mathematical Operations - Multiply,Subtract,Powerof

# %%
list2 = [3,2,1]
array2 = np.array(list2)
print("Multiplication of Array1 with Array2 gives",(array2*array1))
# Out:
# Multiplication of Array1 with Array2 gives [3 4 3]

# %%
list2 = [3,2,1]
array2 = np.array(list2)
print("Division of Array1 with Array2 gives",(array2/array1))
# Out:
# Division of Array1 with Array2 gives [3.         1.         0.33333333]

# %%
list2 = [3,2,1]
array2 = np.array(list2)
print("Powerof of Array1 with Array2 gives",(array2**array1))
# Out:
# Powerof of Array1 with Array2 gives [3 4 1]

# %% [markdown]
# ##6.Implement np.sin(), log(), log2(), np.exp())

# %%
#sine function
print("Sine: ",np.sin(array1))
#logarithm
print("Natural logarithm: ",np.log(array1))
print("Base-10 logarithm: ",np.log10(array1))
print("Base-2 logarithmn: ",np.log2(array1))
#Exponential
print("Exponential: ",np.exp(array1))
# Out:
# Sine:  [0.84147098 0.90929743 0.14112001]
# Natural logarithm:  [0.         0.69314718 1.09861229]
# Base-10 logarithm:  [0.         0.30103    0.47712125]
# Base-2 logarithmn:  [0.        1.        1.5849625]
# Exponential:  [ 2.71828183  7.3890561  20.08553692]

# %% [markdown]
# ##Part 2 – Visualization of Data using matplotlib, pyplots Packages
# 1. Generate a Data set for Health Care using the following:
# people = [’kiran’, arun’, ’vijay’, ’varun’]
# age =[25, 30, 35, 40, 45]
# height =[145, 151, 165, 173]
# weight=[45, 55, 65, 75]
# 2. Using the generated dataset given above. Generate the following graphs and justify the
# relationships among the vectors.
# 3. Scatter Plot
# 4. Bar Chart
# 5. Histogram
# 6. Provide Graph Title, labels for X, Y axis with proper justification and explaination of
# the graph.

# %% [markdown]
# ##3.Scatter Plot

# %% [markdown]
# Scatterplot-basic

# %%
people = ['Ann','Brandon','Chen']
age = [21,12,32]
weight = [55,35,77]
height = [160,135,170]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(age, height)
plt.title("Relationship between Age and Height of Patients.")
plt.ylabel("Height in Meters")
plt.xlabel("Age in years")
plt.show()

# %%
plt.scatter(weight, height)
plt.show()

# %% [markdown]
# ##4.Bar Chart

# %%
plt.figure(figsize=(3,4))
plt.title("People's weight in kgs",fontsize=16,fontstyle='italic')
#Main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# ##5.Histogram

# %%
import numpy as np
plt.figure(figsize=(7,5))

#Main plot function 'hist'
plt.hist(weight,color='orange',edgecolor='k',alpha=0.75,bins=3)
plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ##Part 3 – Access Data from Various Data Sources using builtin Function of Numpy, Pandas
# 1. Generate your own dataset using MS Excel and Notepad to prepare the dataset. Save
# it in Google Drive and access it in Google Colab.
# 2. Upload the text file using tab seperated value(.tsv) and access the data from the file.
# 3. Upload the text file using comma seperated value(.csv) and access the data from file.
# 4. Access the excel file using .xlsx
# 5. Access the text from the URL
